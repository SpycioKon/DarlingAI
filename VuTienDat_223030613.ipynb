# %% [markdown]
# # GIỚI THIỆU THƯ VIỆN SEABORN

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import seaborn as sns
# %matplotlib inline

# %%
# datpc dep trai :)))
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import seaborn as sns
# %matplotlib inline

# %%
sns.__version__
# Out:
# '0.13.1'

# %%
print(sns.__version__)
# Out:
# 0.12.2

# %%
# load in data and save to a variable
#df = seaborn.load_dataset("tips")
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  fraction
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
df=pd.read_csv('tips.csv')
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  fraction
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808
# 5       25.29  4.71    Male     No  Sun  Dinner     4  0.186240
# 6        8.77  2.00    Male     No  Sun  Dinner     2  0.228050
# 7       26.88  3.12    Male     No  Sun  Dinner     4  0.116071
# 8       15.04  1.96    Male     No  Sun  Dinner     2  0.130319
# 9       14.78  3.23    Male     No  Sun  Dinner     2  0.218539

# %% [markdown]
# ### Swarm plots

# %%
import warnings
warnings.filterwarnings('ignore')
seaborn.swarmplot(x="day", y="tip", data=df)
seaborn.set_style("whitegrid")
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
seaborn.swarmplot(x="sex", y="tip", data=df)
seaborn.set_style("whitegrid")
plt.show()

# %%
gender_palette = ["#A833FF", "#FFAF33"]
seaborn.swarmplot(x="day", y="tip", hue="sex", palette=gender_palette, data=df)
plt.show()

# %%
gender_palette = ["red", "black"]
seaborn.swarmplot(x="day", y="tip", hue="sex", palette=gender_palette, data=df)
plt.show()

# %%
seaborn.swarmplot(x="smoker", y="total_bill", 
                  data=df, palette="husl", order=["Yes", "No"])
plt.show()

# %%
seaborn.swarmplot(x="smoker", y="total_bill", 
                  data=df, palette="husl", order=["Yes", "No"])
plt.show()

# %% [markdown]
# ### Violin Plots

# %%
seaborn.violinplot(x = df["tip"], color="gold")
plt.show()

# %%
seaborn.violinplot(x = df["total_bill"], color="red")
plt.show()

# %%
seaborn.violinplot(x = "sex",y ="total_bill",data=df)
plt.show()

# %%
seaborn.violinplot(x = "sex",y ="tip",data=df)
plt.show()

# %%
seaborn.violinplot(x = "time",y ="tip",data=df, 
                   hue ="sex",palette ="dark",split = True)
plt.legend()
plt.show()

# %%
seaborn.violinplot(x = "time",y ="tip",data=df, 
                   hue ="sex",palette ="dark",split = True)
plt.legend()
plt.show()

# %% [markdown]
# ### Facet Grids

# %%
import pandas as pd
pd.DataFrame.iteritems = pd.DataFrame.items

# %%
import pandas as pd
pd.DataFrame.iteritems = pd.DataFrame.items

# %%
g = sns.FacetGrid(df, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(df, col="time",  row="sex")
g.map(sns.histplot, "total_bill", "tip")

# %%
fg = seaborn.FacetGrid(df,col = "time",row = "sex")
fg = fg.map(plt.hist,"tip", color ="tomato")

# %%
fg = seaborn.FacetGrid(df,col = "time",row = "sex")
fg = fg.map(plt.hist,"tip", color ="black")

# %%
g = sns.FacetGrid(df, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(df, col="time",  row="sex")
g.map(sns.lineplot, "total_bill", "tip")

# %%
x = seaborn.FacetGrid(df, col="time", hue="sex")
x = x.map(plt.scatter,"total_bill","tip")
x =x.add_legend()

# %%
x = seaborn.FacetGrid(df, col="smoker", hue="sex")
x = x.map(plt.scatter,"total_bill","tip")
x =x.add_legend()

# %%
# vẽ biểu đồ tần suất phân phối theo ngày 

np.arr

# %% [markdown]
# # pairplot

# %%
sns.pairplot(df,kind="kde",hue="sex")

# %% [markdown]
# ### Heat Maps

# %%
uniform_data = np.random.rand(5, 3) # five rows, 3 columns
print(uniform_data)
seaborn.heatmap(uniform_data)
plt.show()
# Out:
# [[0.78107549 0.79628071 0.07783139]
#  [0.69373072 0.70561998 0.00587663]
#  [0.54671427 0.19570637 0.33103028]
#  [0.15545136 0.16508407 0.44725586]
#  [0.8633854  0.85920407 0.21838203]]

# %%
uniform_data = np.random.rand(6, 3) # five rows, 3 columns
print(uniform_data)
seaborn.heatmap(uniform_data)
plt.show()
# Out:
# [[0.44496813 0.71937615 0.40184404]
#  [0.1053936  0.51530815 0.20254398]
#  [0.81545494 0.71180301 0.31361999]
#  [0.70296645 0.88639996 0.24328351]
#  [0.9582006  0.80404198 0.76063194]
#  [0.82033171 0.23810026 0.28041596]]

# %%
flights = seaborn.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = seaborn.load_dataset("flights")
flights.head(10)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119

# %%
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")
flights_pivot.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")
flights_pivot.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")
flights_pivot.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
# draw border
x = seaborn.heatmap(flights_pivot, linewidths=0.3)

# %%
x = seaborn.heatmap(flights_pivot, annot=True, fmt="d", cmap="YlGnBu")

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  fraction
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808
# 5       25.29  4.71    Male     No  Sun  Dinner     4  0.186240
# 6        8.77  2.00    Male     No  Sun  Dinner     2  0.228050
# 7       26.88  3.12    Male     No  Sun  Dinner     4  0.116071
# 8       15.04  1.96    Male     No  Sun  Dinner     2  0.130319
# 9       14.78  3.23    Male     No  Sun  Dinner     2  0.218539

# %%
konchan = pd.pivot_table(df,values="total_bill", index="day", columns="sex", aggfunc='sum')
sns.heatmap(konchan,annot=True, cmap="YlGnBu")
# Out:
# <Axes: xlabel='sex', ylabel='day'>

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#10 biểu đồ
sns.histplot(diamonds['price'], bins=50, kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x='cut', y='price', data=diamonds)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.violinplot(x='color', y='price', data=diamonds)
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', data=diamonds.sample(1000), alpha=0.5)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.pairplot(diamonds.sample(500), vars=["carat", "depth", "table", "price"], hue="cut")

# %%
sns.barplot(x='cut', y='price', data=diamonds)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
corr = diamonds.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm").set_title("Heatmap of Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation Matrix')

# %%
sns.kdeplot(diamonds['carat'], shade=True)
# Out:
# <Axes: xlabel='carat', ylabel='Density'>

# %%
sns.swarmplot(x='clarity', y='price', data=diamonds.sample(1000))
# Out:
# <Axes: xlabel='clarity', ylabel='price'>

# %%
g = sns.FacetGrid(diamonds, col="cut", col_wrap=3, height=4)
g.map(sns.histplot, "price", bins=50, kde=True)
plt.suptitle("FacetGrid of Price Distribution by Cut", y=1.02)
# Out:
# Text(0.5, 1.02, 'FacetGrid of Price Distribution by Cut')

# %% [markdown]
# ### Box plot

# %%
sns.catplot(data=df, x="day", y="total_bill", kind="box")

# %%
sns.catplot(data=df, x="day", y="total_bill", hue="smoker", kind="box")

# %% [markdown]
# ### Bar plot

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(data=titanic, x="sex", y="survived", hue="class", kind="bar")

# %%
sns.catplot(data=titanic, x="deck", kind="count")

# %% [markdown]
# ### Linear Regression

# %%
tips = sns.load_dataset("tips")

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()

# Load the brain networks example dataset
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Select a subset of the networks
used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Create a categorical palette to identify the networks
network_pal = sns.husl_palette(8, s=.45)
network_lut = dict(zip(map(str, used_networks), network_pal))

# Convert the palette to vectors that will be drawn on the side of the matrix
networks = df.columns.get_level_values("network")
network_colors = pd.Series(networks, index=df.columns).map(network_lut)

# Draw the full plot
g = sns.clustermap(df.corr(), center=0, cmap="vlag",
                   row_colors=network_colors, col_colors=network_colors,
                   dendrogram_ratio=(.1, .2),
                   cbar_pos=(.02, .32, .03, .2),
                   linewidths=.75, figsize=(12, 13))

g.ax_row_dendrogram.remove()
